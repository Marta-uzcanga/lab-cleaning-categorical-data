# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
display(customer_df.shape)
# Out:
# (9134, 24)

# %%
categorical_df = customer_df.select_dtypes(exclude=[np.number])
categorical_df.head()
# Out:
#   Customer       State Response  Coverage Education Effective To Date  \
# 0  BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1  QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2  AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3  WW63253  California       No     Basic  Bachelor           1/20/11
# 4  HB64268  Washington       No     Basic  Bachelor            2/3/11
#
#   EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# ...

# %%
categorical_df.isnull().sum()
# Out:
# Customer             0
# State                0
# Response             0
# Coverage             0
# Education            0
# Effective To Date    0
# EmploymentStatus     0
# Gender               0
# Location Code        0
# Marital Status       0
# Policy Type          0
# Policy               0
# Renew Offer Type     0
# Sales Channel        0
# Vehicle Class        0
# Vehicle Size         0
# dtype: int64

# %%
#there are no null values

# %%
categorical_df.nunique()
# Out:
# Customer             9134
# State                   5
# Response                2
# Coverage                3
# Education               5
# Effective To Date      59
# EmploymentStatus        5
# Gender                  2
# Location Code           3
# Marital Status          3
# Policy Type             3
# Policy                  9
# Renew Offer Type        4
# Sales Channel           4
# Vehicle Class           6
# Vehicle Size            3
# dtype: int64

# %%
categorical_df.dtypes
# Out:
# Customer             object
# State                object
# Response             object
# Coverage             object
# Education            object
# Effective To Date    object
# EmploymentStatus     object
# Gender               object
# Location Code        object
# Marital Status       object
# Policy Type          object
# Policy               object
# Renew Offer Type     object
# Sales Channel        object
# Vehicle Class        object
# Vehicle Size         object
# dtype: object

# %%
#I think customer and 'effective to date' could be numerical. The range is too big in both of them to be categorical, in my opninion.

# %%
#for customer I will get rid of the letters and then check if there are still the same amount fo unique values. if they are not repeated without the letters then it is ok to remove them.

# %%
categorical_df['Customer'].nunique()
# Out:
# 9134

# %%
categorical_df['Customer'] = categorical_df.Customer.str.replace(r"[a-zA-Z]",'')
# Out:
# C:\Users\marta\AppData\Local\Temp/ipykernel_12320/3698376304.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   categorical_df['Customer'] = categorical_df.Customer.str.replace(r"[a-zA-Z]",'')
# C:\Users\marta\AppData\Local\Temp/ipykernel_12320/3698376304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_df['Customer'] = categorical_df.Customer.str.replace(r"[a-zA-Z]",'')

# %%
categorical_df['Customer']
# Out:
# 0        79786
# 1        44356
# 2        49188
# 3        63253
# 4        64268
#          ...
# 9129     72316
# 9130     87824
# 9131     14365
# 9132     19263
# 9133    167826
# Name: Customer, Length: 9134, dtype: object

# %%
categorical_df['Customer'].nunique()
# Out:
# 8688

# %%
#it changes the unique values so this would not be a good approach

# %%
categorical_df.head()
# Out:
#   Customer       State Response  Coverage Education Effective To Date  \
# 0    79786  Washington       No     Basic  Bachelor           2/24/11
# 1    44356     Arizona       No  Extended  Bachelor           1/31/11
# 2    49188      Nevada       No   Premium  Bachelor           2/19/11
# 3    63253  California       No     Basic  Bachelor           1/20/11
# 4    64268  Washington       No     Basic  Bachelor            2/3/11
#
#   EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# ...

# %%
#changing date into numerical
categorical_df['Effective To Date'] =  pd.to_datetime(categorical_df['Effective To Date'])
# Out:
# C:\Users\marta\AppData\Local\Temp/ipykernel_12320/2981725974.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_df['Effective To Date'] =  pd.to_datetime(categorical_df['Effective To Date'])

# %%
categorical_df.head()
# Out:
#   Customer       State Response  Coverage Education Effective To Date  \
# 0    79786  Washington       No     Basic  Bachelor        2011-02-24
# 1    44356     Arizona       No  Extended  Bachelor        2011-01-31
# 2    49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3    63253  California       No     Basic  Bachelor        2011-01-20
# 4    64268  Washington       No     Basic  Bachelor        2011-02-03
#
#   EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# ...

# %%
categorical_df['Effective To Date'] = categorical_df['Effective To Date'].apply(lambda x: x.value)
# Out:
# C:\Users\marta\AppData\Local\Temp/ipykernel_12320/1467627024.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_df['Effective To Date'] = categorical_df['Effective To Date'].apply(lambda x: x.value)

# %%
categorical_df.head()
# Out:
#   Customer       State Response  Coverage Education    Effective To Date  \
# 0    79786  Washington       No     Basic  Bachelor  1298505600000000000
# 1    44356     Arizona       No  Extended  Bachelor  1296432000000000000
# 2    49188      Nevada       No   Premium  Bachelor  1298073600000000000
# 3    63253  California       No     Basic  Bachelor  1295481600000000000
# 4    64268  Washington       No     Basic  Bachelor  1296691200000000000
#
#   EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# ...

# %%
categorical_df['Effective To Date'] = categorical_df['Effective To Date']/100000000000
#to rmeove extra 0
# Out:
# C:\Users\marta\AppData\Local\Temp/ipykernel_12320/2751438476.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_df['Effective To Date'] = categorical_df['Effective To Date']/100000000000

# %%
categorical_df.head()
# Out:
#   Customer       State Response  Coverage Education  Effective To Date  \
# 0    79786  Washington       No     Basic  Bachelor         12985056.0
# 1    44356     Arizona       No  Extended  Bachelor         12964320.0
# 2    49188      Nevada       No   Premium  Bachelor         12980736.0
# 3    63253  California       No     Basic  Bachelor         12954816.0
# 4    64268  Washington       No     Basic  Bachelor         12966912.0
#
#   EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# ...

# %%
categorical_df['Policy']
# Out:
# 0       Corporate L3
# 1        Personal L3
# 2        Personal L3
# 3       Corporate L2
# 4        Personal L1
#             ...
# 9129     Personal L1
# 9130    Corporate L3
# 9131    Corporate L2
# 9132     Personal L2
# 9133    Corporate L3
# Name: Policy, Length: 9134, dtype: object

# %%
categorical_df['Policy Type']
# Out:
# 0       Corporate Auto
# 1        Personal Auto
# 2        Personal Auto
# 3       Corporate Auto
# 4        Personal Auto
#              ...
# 9129     Personal Auto
# 9130    Corporate Auto
# 9131    Corporate Auto
# 9132     Personal Auto
# 9133    Corporate Auto
# Name: Policy Type, Length: 9134, dtype: object

# %%
categorical_df['Policy'].unique()
# Out:
# array(['Corporate L3', 'Personal L3', 'Corporate L2', 'Personal L1',
#        'Special L2', 'Corporate L1', 'Personal L2', 'Special L1',
#        'Special L3'], dtype=object)

# %%
categorical_df['Policy Type'].unique()
# Out:
# array(['Corporate Auto', 'Personal Auto', 'Special Auto'], dtype=object)

# %%
#Policy contains subcategories of Policy Type

# %%
#Policy Type does no add any extra information, Policy contains all the onfirmation. "Auto" in policy type does not add any informtion because they are all auto policies. 
#Policy can be dropped without losing any information

# %%
categorical_df.drop(columns=['Policy Type'])
# Out:
#      Customer       State Response  Coverage Education  Effective To Date  \
# 0       79786  Washington       No     Basic  Bachelor         12985056.0
# 1       44356     Arizona       No  Extended  Bachelor         12964320.0
# 2       49188      Nevada       No   Premium  Bachelor         12980736.0
# 3       63253  California       No     Basic  Bachelor         12954816.0
# 4       64268  Washington       No     Basic  Bachelor         12966912.0
# ...       ...         ...      ...       ...       ...                ...
# 9129    72316  California       No     Basic  Bachelor         12972960.0
# 9130    87824  California      Yes  Extended   College         12974688.0
# 9131    14365  California       No  Extended  Bachelor         12969504.0
# 9132    19263  California       No  Extended   College         12966912.0
# 9133   167826  California       No  Extended   College         12976416.0
#
#      EmploymentStatus Gender Location Code Marital Status        Policy  \
# ...
